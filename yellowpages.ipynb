# %% [markdown]
# <a href="https://colab.research.google.com/github/meenapushpa/micontactscraper/blob/main/yellowpages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
# !pip install requests
# !pip install lxml
# !pip install unicodecsv
# !pip install csv
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (4.2.6)
# Collecting unicodecsv
#   Downloading https://files.pythonhosted.org/packages/6f/a4/691ab63b17505a26096608cc309960b5a6bdf39e4ba1a793d5f9b1a53270/unicodecsv-0.14.1.tar.gz
# Building wheels for collected packages: unicodecsv
#   Building wheel for unicodecsv (setup.py) ... done
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-cp37-none-any.whl size=10768 sha256=bbdb9eb64e05212f1ccdff474f8c558ad14bd9b3966c55c79f25bf1b520a5f3c
#   Stored in directory: /root/.cache/pip/wheels/a6/09/e9/e800279c98a0a8c94543f3de6c8a562f60e51363ed26e71283
# Successfully built unicodecsv
# Installing collected packages: unicodecsv
# Successfully installed unicodecsv-0.14.1
# ERROR: Could not find a version that satisfies the requirement csv (from versions: none)
# ERROR: No matching distribution found for csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-45e99714-2022-4324-9a5c-774a121fef53" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45e99714-2022-4324-9a5c-774a121fef53">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving output.csv to output.csv
# Saving output1.csv to output1.csv
# Saving yellowpages-scraped-data.csv to yellowpages-scraped-data.csv

# %%
import requests
from lxml import html
import unicodecsv as csv
from csv import DictReader
import re
from requests.packages.urllib3.exceptions import InsecureRequestWarning
requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

def parse_listing(keyword, place):
    """
    Function to process yellowpage listing page
    : param keyword: search query
    : param place : place name
    """
    url = "https://www.yellowpages.com/search?search_terms={0}&geo_location_terms={1}".format(keyword, place)

    print("retrieving ", url)

    headers = {'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
               'Accept-Encoding': 'gzip, deflate, br',
               'Accept-Language': 'en-GB,en;q=0.9,en-US;q=0.8,ml;q=0.7',
               'Cache-Control': 'max-age=0',
               'Connection': 'keep-alive',
               'Host': 'www.yellowpages.com',
               'Upgrade-Insecure-Requests': '1',
               'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.140 Safari/537.36'
               }

    # Adding retries
    for retry in range(10):
        response = requests.get(url, verify=False, headers=headers)
        if response.status_code == 200:
            parser = html.fromstring(response.text)
            # making links absolute
            base_url = "https://www.yellowpages.com"
            parser.make_links_absolute(base_url)

            XPATH_LISTINGS = "//div[@class='search-results organic']//div[@class='v-card']"
            listings = parser.xpath(XPATH_LISTINGS)
            scraped_results = []

            for results in listings:
                XPATH_BUSINESS_NAME = ".//a[@class='business-name']//text()"
                XPATH_BUSSINESS_PAGE = ".//a[@class='business-name']//@href"
                XPATH_TELEPHONE = ".//div[@class='phones phone primary']//text()"
                XPATH_ADDRESS = ".//div[@class='info']//div//p[@itemprop='address']"
                XPATH_STREET = ".//div[@class='street-address']//text()"
                XPATH_LOCALITY = ".//div[@class='locality']//text()"
                XPATH_REGION = ".//div[@class='info']//div//p[@itemprop='address']//span[@itemprop='addressRegion']//text()"
                XPATH_ZIP_CODE = ".//div[@class='info']//div//p[@itemprop='address']//span[@itemprop='postalCode']//text()"
                XPATH_RANK = ".//div[@class='info']//h2[@class='n']/text()"
                XPATH_CATEGORIES = ".//div[@class='info']//div[contains(@class,'info-section')]//div[@class='categories']//text()"
                XPATH_WEBSITE = ".//div[@class='info']//div[contains(@class,'info-section')]//div[@class='links']//a[contains(@class,'website')]/@href"
                XPATH_RATING = ".//div[@class='info']//div[contains(@class,'info-section')]//div[contains(@class,'result-rating')]//span//text()"

                raw_business_name = results.xpath(XPATH_BUSINESS_NAME)
                raw_business_telephone = results.xpath(XPATH_TELEPHONE)
                raw_business_page = results.xpath(XPATH_BUSSINESS_PAGE)
                raw_categories = results.xpath(XPATH_CATEGORIES)
                raw_website = results.xpath(XPATH_WEBSITE)
                raw_rating = results.xpath(XPATH_RATING)
                # address = results.xpath(XPATH_ADDRESS)
                raw_street = results.xpath(XPATH_STREET)
                raw_locality = results.xpath(XPATH_LOCALITY)
                raw_region = results.xpath(XPATH_REGION)
                raw_zip_code = results.xpath(XPATH_ZIP_CODE)
                raw_rank = results.xpath(XPATH_RANK)

                business_name = ''.join(raw_business_name).strip() if raw_business_name else None
                telephone = ''.join(raw_business_telephone).strip() if raw_business_telephone else None
                business_page = ''.join(raw_business_page).strip() if raw_business_page else None
                rank = ''.join(raw_rank).replace('.\xa0', '') if raw_rank else None
                category = ','.join(raw_categories).strip() if raw_categories else None
                website = ''.join(raw_website).strip() if raw_website else None
                rating = ''.join(raw_rating).replace("(", "").replace(")", "").strip() if raw_rating else None
                street = ''.join(raw_street).strip() if raw_street else None
                if raw_locality:
                     locality = ''.join(raw_locality).replace(',\xa0', '').strip()
                     locality, locality_parts = locality.split(',')
                     _, region, zipcode = locality_parts.split(' ')
                else:
                    locality,locality_parts ,region,zipcode=None,None,None,None
                business_details = {
                        'business_name': business_name,
                        'telephone': telephone,
                        'category': category,
                        'website': website,
                        'street': street,
                        'locality': locality,
                        'region': region,
                        'zipcode': zipcode
                    }
                scraped_results.append(business_details)
            return scraped_results

        elif response.status_code == 404:
            print("Could not find a location matching", place)
            # no need to retry for non existing page
            break
        else:
            print("Failed to process page")
            return []

def remove_duplicates():
    with open('output.csv', 'rb') as inputfile:
        with open('output1.csv', 'wb') as outputfile:
            duplicatereader = csv.DictReader(inputfile)
            uniquewrite = csv.DictWriter(outputfile, fieldnames=['BorrowerName', 'BorrowerAddress', 'BorrowerCity', 'BorrowerZip','BorrowerState'])
            uniquewrite.writeheader()
            keysread = []
            for row in duplicatereader:
               key = (row['BorrowerName'])
               key = re.sub('[^\w]+', '', key, flags=re.U)
               if key not in keysread:
                   keysread.append(key)
                   uniquewrite.writerow(row)


if __name__ == "__main__":
    remove_duplicates()
    with open('output1.csv', 'r') as read_obj, open('yellowpages-scraped-data.csv', 'wb') as csvfile:
        csv_dict_reader = DictReader(read_obj)
        fieldnames = [ 'business_name', 'telephone', 'email','category', 'website','street', 'locality', 'region', 'zipcode']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames, quoting=csv.QUOTE_ALL)
        writer.writeheader()
        for row in csv_dict_reader:
            name=row['BorrowerName']
            address=row['BorrowerAddress']
            city=row['BorrowerCity']
            zip=row['BorrowerZip']
            state=row['BorrowerState']
            keyword = name
            place = address + city + zip + state
            scraped_data = parse_listing(keyword, place)
            email_headers = {
                       'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.140 Safari/537.36'
                       }
            if scraped_data:
                updated=True
                if scraped_data[0]['website']:
                    try:
                        emailresponse = requests.get(scraped_data[0]['website'],verify=False,headers=email_headers)
                        if emailresponse.status_code == 200:
                            emails = set(re.findall(r"[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.[a-z]+", emailresponse.text, re.I))
                            for i in emails:
                                scraped_data[0]['email']=i
                        elif emailresponse.status_code == 404:
                            print("Could not find a address field")
                        else:
                            scraped_data[0]['email']=None
                            print("Site is temporarily down!")
                    except requests.exceptions.ConnectionError:
                        emailresponse.status_code = "Connection refused"
                else:
                    scraped_data[0]['email']=None
                    print('URL & Email Not Found!!')
            else:
                updated=False
            if updated:
                    writer.writerow(scraped_data[0])
# Out:
# retrieving  https://www.yellowpages.com/search?search_terms=DETROIT MOBILITY GROUP&geo_location_terms=0  6001 Cass AveDETROIT48202-3423MI
# retrieving  https://www.yellowpages.com/search?search_terms=CES LIMITED LLC&geo_location_terms=100 W KIRBY STDETROIT48202-4044MI
# retrieving  https://www.yellowpages.com/search?search_terms=COMPUTECH GLOBAL&geo_location_terms=100 W KIRBY ST 201DETROIT48202-4044MI
# retrieving  https://www.yellowpages.com/search?search_terms=DETROIT GUARDS LLC&geo_location_terms=100 W. Kirby St. Suite 206DETROIT48202-4044MI
# retrieving  https://www.yellowpages.com/search?search_terms=THE INTERNATIONAL INSTITUTE OF METROPOLITAN DETROIT, INC&geo_location_terms=111 E Kirby StDETROIT48202-4003MI
# Could not find a location matching 111 E Kirby StDETROIT48202-4003MI
# retrieving  https://www.yellowpages.com/search?search_terms=OK 2 PLAYY, INC.&geo_location_terms=111 E. Kirby StreetDETROIT48202MI
# URL & Email Not Found!!
# retrieving  https://www.yellowpages.com/search?search_terms=SHOULDERS ABOVE THE REST JANITORIAL&geo_location_terms=111 E. Kirby StreetDETROIT48202MI
# URL & Email Not Found!!
# retrieving  https://www.yellowpages.com/search?search_terms=GAYANGA CO&geo_location_terms=1120 W Baltimore St Ste 200DETROIT48202-2906MI
# retrieving  https://www.yellowpages.com/search?search_terms=GAYANGA CO LLC&geo_location_terms=1120 W Baltimore Ste 200DETROIT48202MI
# retrieving  https://www.yellowpages.com/search?search_terms=WHITE CONSTRUCTION&geo_location_terms=1120 W. BALTIMORE STDETROIT48202-2906MI
# retrieving  https://www.yellowpages.com/search?search_terms=ELECTRIC MOTOR & CONTRACTING C&geo_location_terms=1133 W. BaltimoreDETROIT48202MI
# retrieving  https://www.yellowpages.com/search?search_terms=NICHOLE CALME&geo_location_terms=1153 Seward StDETROIT48202-2308MI
# retrieving  https://www.yellowpages.com/search?search_terms=HAMILTON FUEL MART LLC&geo_location_terms=11567 Hamilton AveDETROIT48202-1012MI
# URL & Email Not Found!!
# retrieving  https://www.yellowpages.com/search?search_terms=360 DETROIT, INC&geo_location_terms=1159 W EuclidDETROIT48202MI
# URL & Email Not Found!!
# retrieving  https://www.yellowpages.com/search?search_terms=MIKOSCATER&geo_location_terms=1161 burlingame , Detroit, Michigan, 48202DETROIT48202MI
# retrieving  https://www.yellowpages.com/search?search_terms=UNIVERSAL AUTO TECH LLC&geo_location_terms=11615 WOODWARD AVEDETROIT48202-1130MI
# retrieving  https://www.yellowpages.com/search?search_terms=BORDER CITY CHURCH&geo_location_terms=1180 SEWARD ST UNIT 1DETROIT48202MI
# retrieving  https://www.yellowpages.com/search?search_terms=CYNTHIA JEWELL&geo_location_terms=119 Virginia ParkDETROIT48202MI
# URL & Email Not Found!!
# retrieving  https://www.yellowpages.com/search?search_terms=INTOTO STUDIO LLC&geo_location_terms=12 W Milwaukee St Suite 200DETROIT48202MI
# Could not find a location matching 12 W Milwaukee St Suite 200DETROIT48202MI
# retrieving  https://www.yellowpages.com/search?search_terms=KEVIN DANIEL JR&geo_location_terms=1203 W Euclid StDETROIT48202-1946MI
# URL & Email Not Found!!
# retrieving  https://www.yellowpages.com/search?search_terms=ONE STOP PROPERTY MAINTENANCE LLC&geo_location_terms=1210 LONGFELLOW STDETROIT48202-1545MI
# retrieving  https://www.yellowpages.com/search?search_terms=MANTU JUDKINS&geo_location_terms=1216 pingreeDETROIT48202MI
# Could not find a location matching 1216 pingreeDETROIT48202MI
# retrieving  https://www.yellowpages.com/search?search_terms=CRAFT CREATIVE CATERING LLC&geo_location_terms=122 ENGLEWOOD STDETROIT48202-1152MI
# URL & Email Not Found!!
# retrieving  https://www.yellowpages.com/search?search_terms=KELSEY CLARK CREATIVE, LLC&geo_location_terms=127 Seward Ave Apt 110DETROIT48202MI
# retrieving  https://www.yellowpages.com/search?search_terms=TEA&geo_location_terms=1314 Holden StDETROIT48202-3326MI
# URL & Email Not Found!!
# retrieving  https://www.yellowpages.com/search?search_terms
# retrieving  https://www.yellowpages.com/search?search_terms=TONY VS TAVERN&geo_location_terms=5756 Cass AveDETROIT48202-3629MI
# retrieving  https://www.yellowpages.com/search?search_terms=INDUSTRIAL SEWING AND INNOVATION CENTER (ISAIC)&geo_location_terms=5800 Cass Ave Ste 43DETROIT48202-3452MI
# retrieving  https://www.yellowpages.com/search?search_terms=GREATER NEW MOUNT MORIAH MISSIONARY BAPTIST CHURCH&geo_location_terms=586 Owen StDETROIT48202-1819MI
# retrieving  https://www.yellowpages.com/search?search_terms=GREATER NEW MT MORIAH BAPTIST CHURCH&geo_location_terms=586 Owen StDETROIT48202-1819MI
# retrieving  https://www.yellowpages.com/search?search_terms=JEP HOMES LLC&geo_location_terms=59 Burlingame StDETROIT48202-1002MI
# URL & Email Not Found!!
# retrieving  https://www.yellowpages.com/search?search_terms=KAYLA PERRIN&geo_location_terms=5950 JOHN R STDETROIT48202-3574MI
# retrieving  https://www.yellowpages.com/search?search_terms=DAWN JONES&geo_location_terms=5951 JOHN R ST Apt 8DETROIT48202-3573MI
# URL & Email Not Found!!
# retrieving  https://www.yellowpages.com/search?search_terms=LONDON LUGGAGE SHOP&geo_location_terms=5955 Woodward AveDETROIT48202-3515MI
# retrieving  https://www.yellowpages.com/search?search_terms=WOODWARD FUEL INC&geo_location_terms=5996 woodwardDETROIT48202MI
# retrieving  https://www.yellowpages.com/search?search_terms=WOODWARD SUBWAY INC&geo_location_terms=5996 woodwardDETROIT48202MI
# retrieving  https://www.yellowpages.com/search?search_terms=3 FOLD AGENCY LLC&geo_location_terms=60 East Milwaukee AvenueDETROIT48202MI
# retrieving  https://www.yellowpages.com/search?search_terms=LEONARD GOUDY&geo_location_terms=60 LawrenceDETROIT48202MI
# Could not find a location matching 60 LawrenceDETROIT48202MI
# retrieving  https://www.yellowpages.com/search?search_terms=GREENFIELD NOODLE & SPECIALTY CO&geo_location_terms=600 Custer StDETROIT48202-3128MI
# URL & Email Not Found!!
# retrieving  https://www.yellowpages.com/search?search_terms=LENIO LLC&geo_location_terms=6001 CASS AVEDETROIT48202-3423MI
# Could not find a location matching 6001 CASS AVEDETROIT48202-3423MI
# retrieving  https://www.yellowpages.com/search?search_terms=SIXTH MAN TECHNOLOGIES INC.&geo_location_terms=6001 CASS AVEDETROIT48202-3423MI
# Could not find a location matching 6001 CASS AVEDETROIT48202-3423MI
# retrieving  https://www.yellowpages.com/search?search_terms=ENDEAVOR DETROIT&geo_location_terms=6001 Cass Ave Ste 3-130DETROIT48202-3423MI
# URL & Email Not Found!!
# retrieving  https://www.yellowpages.com/search?search_terms=RECORDS STORAGE DELIVERY & SERVICE INC&geo_location_terms=6044 John C LodgeDETROIT48202MI
# retrieving  https://www.yellowpages.com/search?search_terms=CONSUMER TIRE CORPORATION&geo_location_terms=6045 John C LodgeDETROIT48202MI
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e4f4d42da98d> in <module>()
#     142                 if scraped_data[0]['website']:
#     143                     try:
# --> 144                         emailresponse = requests.get(scraped_data[0]['website'],verify=False,headers=email_headers)
#     145                         if emailresponse.status_code == 200:
#     146                             emails = set(re.findall(r"[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.[a-z]+", emailresponse.text, re.I))
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.7/http/client.py in getresponse(self)
#    1367         try:
#    1368             try:
# -> 1369                 response.begin()
#    1370             except ConnectionError:
#    1371                 self.close()
#
# /usr/lib/python3.7/http/client.py in begin(self)
#     308         # read until we get a non-100 response
#     309         while True:
# --> 310             version, status, reason = self._read_status()
#     311             if status != CONTINUE:
#     312                 break
#
# /usr/lib/python3.7/http/client.py in _read_status(self)
#     269
#     270     def _read_status(self):
# --> 271         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     272         if len(line) > _MAXLINE:
#     273             raise LineTooLong("status line")
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
